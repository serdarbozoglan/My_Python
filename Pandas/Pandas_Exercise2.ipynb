# %%
import pandas as pd

# %%
orders  = pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
user_cols = ['user_id', 'age', 'gender', 'occupation', 'zip_code']
pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_cols, index_col='user_id')
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 9         29      M        student    01002
# 10        53      M         lawyer    90703
# 11        39      F          other    30329
# 12        28      F          other    06405
# 13        47      M       educator    29206
# 14        45      M      scientist    55106
# 15        49      F       educator    97301
# 16        21      M  entertainment    10309
# 17        30      M     programmer    06355
# 18        35      F          other    37212
# 19        40      M      librarian    02138
# 20        42      F      homemaker    95660
# ...

# %%
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['City']
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
# 5                 Valley City
# 6                 Crater Lake
# 7                        Alma
# 8                     Eklutna
# 9                     Hubbard
# 10                    Fontana
# 11                   Waterloo
# 12                     Belton
# 13                     Keokuk
# 14                  Ludington
# 15                Forest Home
# 16                Los Angeles
# 17                  Hapeville
# 18                     Oneida
# 19                 Bering Sea
# 20                   Nebraska
# 21                        NaN
# 22                        NaN
# 23                  Owensboro
# 24                 Wilderness
# 25                  San Diego
# 26                 Wilderness
# 27                     Clovis
# 28                 Los Alamos
# 29               Ft. Duschene
#                  ...
# ...

# %% [markdown]
# ## CREATING A NEW COLUMN

# %%
ufo['Location'] = ufo['City'] + ',' + ufo['State']

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# ## RENAME COLUMNS

# %%
ufo.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
ufo.rename(columns={'Colors Reported':'Colors_Reported', 'Shape Reported':'Shape_Reported'}, inplace=True)

# %%
ufo.head()
# Out:
#                    City Colors_Reported Shape_Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo_cols = ['city', 'colors reported', 'shape reported', 'state', 'time']
ufo.columns = ufo_cols

# %%
ufo.head()
# Out:
#                    city colors reported shape reported state             time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo2 = pd.read_table('http://bit.ly/uforeports', sep=',', names=ufo_cols, header=0)

# %%
ufo2.head()
# Out:
#                    city colors reported shape reported state             time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.columns = ufo.columns.str.replace(' ', '_')

# %%
ufo.head()
# Out:
#                    city colors_reported shape_reported state             time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.shape
# Out:
# (18241, 5)

# %% [markdown]
# ## DROPING COLUMNS/ROWS

# %%
ufo.drop('colors_reported', axis=1, inplace=True)

# %%
ufo.head()
# Out:
#                    city shape_reported state             time
# 0                Ithaca       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke           OVAL    CO  2/15/1931 14:00
# 3               Abilene           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair          LIGHT    NY  4/18/1933 19:00

# %%
ufo.drop(['city', 'state'], axis=1, inplace=True)

# %%
ufo.head()
# Out:
#   shape_reported             time
# 0       TRIANGLE   6/1/1930 22:00
# 1          OTHER  6/30/1930 20:00
# 2           OVAL  2/15/1931 14:00
# 3           DISK   6/1/1931 13:00
# 4          LIGHT  4/18/1933 19:00

# %%
ufo.drop([1,3], axis=0, inplace=True)

# %%
ufo.head()
# Out:
#   shape_reported             time
# 0       TRIANGLE   6/1/1930 22:00
# 2           OVAL  2/15/1931 14:00
# 4          LIGHT  4/18/1933 19:00
# 5           DISK  9/15/1934 15:30
# 6         CIRCLE   6/15/1935 0:00

# %% [markdown]
# ## HOW TO SORT DF OR SERIES

# %%
movies = pd.read_table('http://bit.ly/imdbratings', sep=',')

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies['title'].sort_values(ascending=False)
# Out:
# 864                                  [Rec]
# 526                                   Zulu
# 615                             Zombieland
# 677                                 Zodiac
# 955                       Zero Dark Thirty
# 535                                  Zelig
# 280                     Young Frankenstein
# 96                                 Yojimbo
# 235                                Yip Man
# 403                             Ying xiong
# 695                      Y Tu Mama Tambien
# 871                                     X2
# 532                     X-Men: First Class
# 248             X-Men: Days of Future Past
# 954                                  X-Men
# 518                         Wreck-It Ralph
# 970                            Wonder Boys
# 65             Witness for the Prosecution
# 920                                Witness
# 483                           Withnail & I
# 270                        Wings of Desire
# 497    Willy Wonka & the Chocolate Factory
# ...

# %%
movies.sort_values('title', ascending=False).head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864          7.5             [Rec]              R  Horror        78
# 526          7.8              Zulu        UNRATED   Drama       138
# 615          7.7        Zombieland              R  Comedy        88
# 677          7.7            Zodiac              R   Crime       157
# 955          7.4  Zero Dark Thirty              R   Drama       157
#
#                                            actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...

# %%
movies.sort_values('duration', ascending=False).head()
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %% [markdown]
# ## FILTERING DATAFRAME

# %%
movies[movies['duration']>150].head()
# Out:
#    star_rating                           title content_rating    genre  \
# 1          9.2                   The Godfather              R    Crime
# 2          9.1          The Godfather: Part II              R    Crime
# 3          9.0                 The Dark Knight          PG-13   Action
# 4          8.9                    Pulp Fiction              R    Crime
# 6          8.9  The Good, the Bad and the Ugly      NOT RATED  Western
#
#    duration                                        actors_list
# 1       175    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3       152  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4       154  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 6       161  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...

# %%
movies[movies['duration']>150]['genre']
# Out:
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
# 6        Western
# 7      Adventure
# 8      Biography
# 10     Adventure
# 14     Adventure
# 15     Adventure
# 17         Drama
# 26       Western
# 36        Action
# 40         Crime
# 43        Action
# 44        Action
# 47         Drama
# 49         Crime
# 50         Drama
# 51         Drama
# 59       Western
# 60        Comedy
# 66        Comedy
# 72         Drama
# 78         Crime
# 82        Action
# 85     Adventure
# 89         Drama
# 93        Comedy
# 99     Biography
#          ...
# 569    Biography
# 611       Comedy
# 613       Action
# 620        Drama
# 630    Biography
# 649       Action
# 665        Drama
# 671       Action
# 677        Crime
# 678        Drama
# 684       Action
# 707       Action
# 711        Crime
# 720        Drama
# 727    Adventure
# 730        Crime
# 731        Drama
# 734        Drama
# 755        Drama
# 767       Action
# 807    Biography
# ...

# %%
movies.loc[movies['duration']>150,'genre']
# Out:
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
# 6        Western
# 7      Adventure
# 8      Biography
# 10     Adventure
# 14     Adventure
# 15     Adventure
# 17         Drama
# 26       Western
# 36        Action
# 40         Crime
# 43        Action
# 44        Action
# 47         Drama
# 49         Crime
# 50         Drama
# 51         Drama
# 59       Western
# 60        Comedy
# 66        Comedy
# 72         Drama
# 78         Crime
# 82        Action
# 85     Adventure
# 89         Drama
# 93        Comedy
# 99     Biography
#          ...
# 569    Biography
# 611       Comedy
# 613       Action
# 620        Drama
# 630    Biography
# 649       Action
# 665        Drama
# 671       Action
# 677        Crime
# 678        Drama
# 684       Action
# 707       Action
# 711        Crime
# 720        Drama
# 727    Adventure
# 730        Crime
# 731        Drama
# 734        Drama
# 755        Drama
# 767       Action
# 807    Biography
# ...

# %%
movies[(movies['duration']>200) & (movies['genre']=='Drama')]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies[movies['genre'].isin(['Drama', 'Action', 'Crime'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
movies[(movies['duration']>50) & (movies['genre'].isin(['Drama, Action']))]
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
ufo  =pd.read_table('http://bit.ly/uforeports', sep=',', usecols=['City', 'State'])

# %%
ufo.head()
# Out:
#                    City State
# 0                Ithaca    NY
# 1           Willingboro    NJ
# 2               Holyoke    CO
# 3               Abilene    KS
# 4  New York Worlds Fair    NY

# %%
ufo = pd.read_csv('http://bit.ly/uforeports', usecols=[0,4], nrows=4)

# %%
ufo
# Out:
#           City             Time
# 0       Ithaca   6/1/1930 22:00
# 1  Willingboro  6/30/1930 20:00
# 2      Holyoke  2/15/1931 14:00
# 3      Abilene   6/1/1931 13:00

# %%
for index, row in ufo.iterrows():
    print(index, row.City, row.Time)
# Out:
# 0 Ithaca 6/1/1930 22:00
# 1 Willingboro 6/30/1930 20:00
# 2 Holyoke 2/15/1931 14:00
# 3 Abilene 6/1/1931 13:00

# %%
drinks = pd.read_table('http://bit.ly/drinksbycountry', sep=',')

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# ## SELECTING NUMERIC OR STRING COLUMNS

# %%
import numpy as np
drinks.select_dtypes(include=[np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %%
drinks.select_dtypes(include=['object']).head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
orders = pd.read_table('http://bit.ly/chiporders')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ## STRING OPERATIONS

# %%
orders['item_name'] = orders['item_name'].str.upper()

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           CHIPS AND FRESH TOMATO SALSA
# 1         1         1                                   IZZE
# 2         1         1                       NANTUCKET NECTAR
# 3         1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4         2         2                           CHICKEN BOWL
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders.rename(columns={'item_name':'ITEM_NAME'}, inplace=True)

# %%
orders.head()
# Out:
#    order_id  quantity                              ITEM_NAME  \
# 0         1         1           CHIPS AND FRESH TOMATO SALSA
# 1         1         1                                   IZZE
# 2         1         1                       NANTUCKET NECTAR
# 3         1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4         2         2                           CHICKEN BOWL
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
orders[orders["ITEM_NAME"].str.contains('CHICKEN')]
# Out:
#       order_id  quantity             ITEM_NAME  \
# 4            2         2          CHICKEN BOWL
# 5            3         1          CHICKEN BOWL
# 11           6         1  CHICKEN CRISPY TACOS
# 12           6         1    CHICKEN SOFT TACOS
# 13           7         1          CHICKEN BOWL
# 16           8         1       CHICKEN BURRITO
# 17           9         1       CHICKEN BURRITO
# 19          10         1          CHICKEN BOWL
# 23          12         1       CHICKEN BURRITO
# 26          13         1          CHICKEN BOWL
# 29          15         1       CHICKEN BURRITO
# 35          18         1    CHICKEN SOFT TACOS
# 36          18         1    CHICKEN SOFT TACOS
# 42          20         1          CHICKEN BOWL
# 44          20         1    CHICKEN SALAD BOWL
# 45          21         1       CHICKEN BURRITO
# 52          24         1       CHICKEN BURRITO
# 63          28         1       CHICKEN BURRITO
# 68          30         1       CHICKEN BURRITO
# ...

# %%
orders['choice_description']  = orders['choice_description'].str.replace('[', '')
orders['choice_description']  = orders['choice_description'].str.replace(']', '')

# %%
orders.head()
# Out:
#    order_id  quantity                              ITEM_NAME  \
# 0         1         1           CHIPS AND FRESH TOMATO SALSA
# 1         1         1                                   IZZE
# 2         1         1                       NANTUCKET NECTAR
# 3         1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4         2         2                           CHICKEN BOWL
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                         Clementine     $3.39
# 2                                              Apple     $3.39
# 3                                                NaN     $2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...    $16.98

# %% [markdown]
# ## CHANGING TYPE OF COLUMN

# %%
drinks['beer_servings'].dtype
# Out:
# dtype('int64')

# %%
drinks['beer_servings'] = drinks['beer_servings'].astype('float')

# %%
drinks['beer_servings'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## CHANGING COLUMN TYPE WHILE READING A FILE

# %%
drinks = pd.read_table('http://bit.ly/drinksbycountry', sep=',',dtype={'beer_servings':'float'})

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %% [markdown]
# ## REMOVING $ FROM A COLUMN

# %%
orders.head()
# Out:
#    order_id  quantity                              ITEM_NAME  \
# 0         1         1           CHIPS AND FRESH TOMATO SALSA
# 1         1         1                                   IZZE
# 2         1         1                       NANTUCKET NECTAR
# 3         1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4         2         2                           CHICKEN BOWL
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                         Clementine     $3.39
# 2                                              Apple     $3.39
# 3                                                NaN     $2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...    $16.98

# %%
orders['item_price'] = orders['item_price'].str.replace('$', '')

# %%
orders.head()
# Out:
#    order_id  quantity                              ITEM_NAME  \
# 0         1         1           CHIPS AND FRESH TOMATO SALSA
# 1         1         1                                   IZZE
# 2         1         1                       NANTUCKET NECTAR
# 3         1         1  CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4         2         2                           CHICKEN BOWL
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                         Clementine      3.39
# 2                                              Apple      3.39
# 3                                                NaN      2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...     16.98

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.groupby('continent')['beer_servings'].mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent')['beer_servings'].agg(['count', 'min', 'max', 'mean'])
# Out:
#                count   min    max        mean
# continent
# Africa            53   0.0  376.0   61.471698
# Asia              44   0.0  247.0   37.045455
# Europe            45   0.0  361.0  193.777778
# North America     23   1.0  285.0  145.434783
# Oceania           16   0.0  306.0   89.687500
# South America     12  93.0  333.0  175.083333

# %%
drinks['continent'].value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks['continent'].value_counts(normalize=True)
# Yuzdelik olarak dondurur
# Out:
# Africa           0.274611
# Europe           0.233161
# Asia             0.227979
# North America    0.119171
# Oceania          0.082902
# South America    0.062176
# Name: continent, dtype: float64

# %%
movies['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies['genre'].nunique()
# Out:
# 16

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
pd.crosstab(movies['genre'], movies['content_rating'])
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %% [markdown]
# ## MISSING VALUES

# %%
ufo = pd.read_table('http://bit.ly/uforeports', sep=',')

# %%
ufo.tail()
# Out:
#               City Colors Reported Shape Reported State              Time
# 18236   Grant Park             NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237  Spirit Lake             NaN           DISK    IA  12/31/2000 23:00
# 18238  Eagle River             NaN            NaN    WI  12/31/2000 23:45
# 18239  Eagle River             RED          LIGHT    WI  12/31/2000 23:45
# 18240         Ybor             NaN           OVAL    FL  12/31/2000 23:59

# %%
ufo.isnull().tail()
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufo.isnull().sum()
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
ufo[ufo['City'].isnull()]
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(how='all').shape # we have not inplaced # shape shows the remaining columns
# Out:
# (18241, 5)

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.drop_duplicates().shape ## we have not inplaced
# Out:
# (18132, 5)

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
ufo.dropna(subset=['City', 'Shape Reported'], how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts(dropna=False) # Shows NaN as well
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# CRESCENT        2
# ROUND           2
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# DOME            1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].fillna(value='VARIOUS', inplace=True) # Filling with a value

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18241 entries, 0 to 18240
# Data columns (total 5 columns):
# City               18216 non-null object
# Colors Reported    2882 non-null object
# Shape Reported     18241 non-null object
# State              18241 non-null object
# Time               18241 non-null object
# dtypes: object(5)
# memory usage: 712.6+ KB

# %%
ufo['Colors Reported'].value_counts().index[0]
# Out:
# 'RED'

# %%
## Filling with most common 
ufo['Colors Reported'].fillna(value=ufo['Colors Reported'].value_counts().index[0])
# Out:
# 0           RED
# 1           RED
# 2           RED
# 3           RED
# 4           RED
# 5           RED
# 6           RED
# 7           RED
# 8           RED
# 9           RED
# 10          RED
# 11          RED
# 12          RED
# 13          RED
# 14          RED
# 15          RED
# 16          RED
# 17          RED
# 18          RED
# 19          RED
# 20          RED
# 21          RED
# 22          RED
# 23          RED
# 24          RED
# 25          RED
# 26          RED
# 27          RED
# 28          RED
# 29          RED
#           ...
# 18211       RED
# 18212       RED
# 18213     GREEN
# 18214       RED
# 18215       RED
# 18216    ORANGE
# 18217       RED
# 18218       RED
# 18219       RED
# 18220      BLUE
# 18221       RED
# 18222       RED
# 18223       RED
# 18224       RED
# 18225       RED
# 18226       RED
# 18227       RED
# 18228       RED
# 18229       RED
# 18230       RED
# 18231       RED
# 18232       RED
# 18233       RED
# 18234       RED
# ...

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.set_index('country', inplace=True)

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.loc[['Albania'], :]
# Out:
#          beer_servings  spirit_servings  wine_servings  \
# country
# Albania           89.0              132             54
#
#          total_litres_of_pure_alcohol continent
# country
# Albania                           4.9    Europe

# %%
drinks.index.name=None

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan            0.0                0              0
# Albania               89.0              132             54
# Algeria               25.0                0             14
# Andorra              245.0              138            312
# Angola               217.0               57             45
#
#              total_litres_of_pure_alcohol continent
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.index.name='country'
drinks.reset_index(inplace=True)

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
drinks.describe().loc['25%', 'beer_servings']
# Out:
# 20.0

# %%
drinks['continent'].value_counts()['Africa']
# Out:
# 53

# %%
drinks['continent'].value_counts().index[0]
# Out:
# 'Africa'

# %%
drinks['continent'].value_counts().sort_values() # values are sorted
# Out:
# South America    12
# Oceania          16
# North America    23
# Asia             44
# Europe           45
# Africa           53
# Name: continent, dtype: int64

# %%
drinks['continent'].value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks['continent'].value_counts().sort_index() # index is sorted
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
import sys

sys.getsizeof(drinks['continent'])
# Out:
# 12436

# %% [markdown]
# ## CONVERTING TO CATEGORY TYPE

# %%
drinks.memory_usage(deep=True)
# Out:
# Index                              80
# country                         12588
# beer_servings                    1544
# spirit_servings                  1544
# wine_servings                    1544
# total_litres_of_pure_alcohol     1544
# continent                       12332
# dtype: int64

# %%
drinks['continent'] = drinks['continent'].astype('category')

# %%
drinks['continent'].head()
# Out:
# 0      Asia
# 1    Europe
# 2    Africa
# 3    Europe
# 4    Africa
# Name: continent, dtype: category
# Categories (6, object): [Africa, Asia, Europe, North America, Oceania, South America]

# %%
drinks['continent'].cat.codes.head()
# Out:
# 0    1
# 1    2
# 2    0
# 3    2
# 4    0
# dtype: int8

# %%
drinks['continent'].cat.categories
# Out:
# Index(['Africa', 'Asia', 'Europe', 'North America', 'Oceania',
#        'South America'],
#       dtype='object')

# %%
sys.getsizeof(drinks['continent'])
# Out:
# 848

# %%
drinks.to_pickle('drinks.pkl')

# %%
drinks2 = pd.read_pickle('drinks.pkl')

# %%
drinks2.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan            0.0                0              0
# 1      Albania           89.0              132             54
# 2      Algeria           25.0                0             14
# 3      Andorra          245.0              138            312
# 4       Angola          217.0               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %% [markdown]
# ## CREATING DUMMY VARIABLES

# %%
train = pd.read_table('http://bit.ly/kaggletrain', sep=',')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train['Sex_male'] = train['Sex'].map({'female':0, 'male':1})

# %%
pd.get_dummies(train['Sex'], prefix='Sex', drop_first=True).head()
# Out:
#    Sex_male
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
pd.get_dummies(train, columns=['Sex', 'Embarked'], drop_first=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## TIMES

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo['Time'] = pd.to_datetime(ufo['Time'])

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
ufo['Time'].dt.weekday_name.head()
# Out:
# 0     Sunday
# 1     Monday
# 2     Sunday
# 3     Monday
# 4    Tuesday
# Name: Time, dtype: object
